# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/course-of-python/blob/main/Examples_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem Statement: Write a Python program to create a simple function that prints a welcome message.
def welcome():
  print('welcome to python functions')
welcome()
# Out:
# welcome to python functions

# %%
#Problem Statement: Write a Python program to create a function that accepts a student name and prints a greeting.
def greeting_student(name): #greeting:hello,hii,bye
  print('Hello',name)
student_name='shivani'
greeting_student(student_name)
# Out:
# Hello shivani

# %%
#Problem Statement: Write a Python program to create a function that adds two numbers and returns the result.
def add_numbers(a,b):
  result= a+b
  return result

answer=add_numbers(10,30)
print('sum',answer)
# Out:
# sum 40

# %%
#Problem Statement: Write a Python program where the output of one function is passed as input to another function.
def square(num):
  return num*num
def double(num):
  return num * 2

result=double(square(5))
print('Final_result',result)
# Out:
# Final_result 50

# %%
#Problem Statement: Write a Python program to create a function with a default parameter value.
def student_name(name='Shivani'):
  print('Selected name:',name)
student_name()
student_name(name='shruti')
# Out:
# Selected name: Shivani
# Selected name: shruti

# %%
#Problem Statement: Write a Python program to call a function using keyword arguments.
def student_details(name,age,city):
  print('name:',name)
  print('age:',age)
  print('city:',city)
student_details(name='shivani',age=23,city='pune')
# Out:
# name: shivani
# age: 23
# city: pune

# %%
#Problem Statement: Write a Python program to create a function that can add any number of values.
def add_all(*numbers):
  total = 0
  for n in numbers:
    total = total + n
  return total
print('total:',add_all(10,20,30,40))
# Out:
# total: 100

# %%
def print_profile(**details):
  for key,value in details.items():
    print(key,':',value)
print_profile(name='shivani',age=23,city='kolhpur')
# Out:
# name : shivani
# age : 23
# city : kolhpur

# %%
# Create a function that takes a number and returns whether it is even or odd
def even_odd(num):
  if num % 2 == 0:
    return('even')
  else:
    return('odd')
print(even_odd(17))
# Out:
# odd

# %%
#Problem Statement: Create a function that accepts three numbers and returns the largest number.
def largest_of_three(a,b,c):
  if a>=b and a >=c:
    return a
  elif b>=a and b>=c:
    return b
  else:
    return c
print(largest_of_three(12,34,56))
# Out:
# 56

# %%
#Problem Statement: Create a function that returns the factorial of a given number.
def factorial(num):
  fact = 1
  while num > 0:
    fact = fact * num
    num = num-1
  return fact
print('factorial',factorial(2))
# Out:
# factorial 2

# %%
#Problem Statement: Create a function that checks whether a number is prime or not.
def is_prime(num):
   if num <= 1:
    return False

i = 2
while i < num:
  if num % i == 0:
    return False
  i = i + 1

return True

# %%
#Problem Statement: Create a function that accepts a string and returns the reversed string.
def reverse_str(text):
  result= ''
  for ch in text:
    result=ch + result
  return result
print(reverse_str('python'))
# Out:
# nohtyp

# %%
#Problem Statement: Create a function that counts vowels in a given string.
def vowels(text):
  vowels='aeiouAeiou'
  count =0

  for ch in text:
    if ch in vowels:
      count=count+1
  return count

print('vovels',vowels('shivani patil'))
# Out:
# vovels 5

# %%
#Problem Statement: Create a function that checks whether a string is palindrome or not.
def is_Palindrome(text):
  result=text.lower()
  return result == result[::-1]

print(is_Palindrome('Madam'))
# Out:
# True

# %%
#8) Problem Statement: Create a function that returns the Fibonacci series for n terms.

# %%
from typing_extensions import ItemsView
#Problem Statement: Create a function that removes duplicate values from a list while maintaining order.
def remove_duplicates(items):
  result=[]

  for item in items:
    if item not in result:
        result.append(item)
  return result

print(remove_duplicates([1,23,45,6,23,45]))
# Out:
# [1, 23, 45, 6]

# %%
def sum_all(*numbers):
  return sum (numbers)
print(sum_all(12,32,56))
# Out:
# 100
