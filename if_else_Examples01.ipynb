# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/course-of-python/blob/main/if_else_Examples01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Write a Python program to find maximum between two numbers.
num1=eval(input('enter the maximum num1:'))
num2=eval(input('enter the maximum num2:'))
if num1>num2:
  print('maximum number is num1:')
else:
  print('maximum number is num2:')
# Out:
# enter the maximum num1:12
# enter the maximum num2:2
# maximum number is num1:

# %%
#2. Write a Python program to find maximum among three numbers.
num1=eval(input('enter the maximum num1:'))
num2=eval(input('enter the maximum num2:'))
num3=eval(input('enter the maximum num3:'))
if num1>num2>num3:
  print('maximum number is num1:')
elif num2>num3:
 print('maximum number is num2:')
else:
 print('maximum number is num3:')
# Out:
# enter the maximum num1:1
# enter the maximum num2:21
# enter the maximum num3:3
# maximum number is num2:

# %%
#3. Write a Python program to check whether a number is negative, positive or zero.
num=int(input('enter the  number:'))
if num>0:
  print('positive')
elif num<0:
  print('Negative')
else:
  print('Zero')
# Out:
# enter the  number:1
# positive

# %%
#4. Write a Python program to check whether a number is divisible by 5 and 11 or not.
num=int(input('Enter the number:'))
if num%5==0 and num%11==0:
  print('It is divisible by both 5 and 11')
else:
  print('It is not divisible by both 5 and 11')
# Out:
# Enter the number:55
# It is divisible by both 5 and 11

# %%
#5. Write a Python program to check whether a number is even or odd.
num=int(input('Enter the number'))
if num%2==0:
  print('Even')
else:
  print('Odd')
# Out:
# Enter the number3
# Odd

# %%
#6. Write a Python program to check whether a year is leap year or not.
year=int(input('Enter a year'))
if(year % 400==0) or (year % 4==0) and(year % 100!=0):
  print(year,"is  leap year")
else:
  print(year,"is not leap year")
# Out:
# Enter a year2024
# 2024 is  leap year

# %%
from re import A
#7. Write a Python program to check whether a character is alphabet or not.
ch=input('Enter the character:')
if ('A' <= ch <= 'Z') or ('a' <= ch <= 'z'):
  print(ch,'is alphabet')
else:
  print(ch,' is not alphabet')
# Out:
# Enter the character:A
# A is alphabet

# %%
#8. Write a Python program to input any alphabet and check whether it is vowel or consonant.
ch = input('Enter the alhabet:')
ch=ch.lower()
if ch in ('a','e','i','o','u'):
  print(ch,'it is a vowel')
else:
  print(ch,'it is constant')
# Out:
# Enter the alhabet:a
# a it is a vowel

# %%
#9. Write a Python program to check whether a character is uppercase or lowercase alphabet.
ch = input('Enter a character:')
if ch.isupper():
  print(ch,'It is Upper case')
elif ch.islower():
  print(ch,'It is lowercase')
else:
  print(ch,'It  is not alhabet')
# Out:
# Enter a character:SHIVANI
# SHIVANI It is Upper case

# %%
#Write a Python program to count total number of notes in given amount.
amt=int(input('Enter a amount'))
count=0
if amt % 500 ==0:
  print('number of 500 notes:',amt//500)
elif amt % 200 == 0:
    print("Number of 200 notes =", amt // 200)
elif amt % 100 == 0:
    print("Number of 100 notes =", amt // 100)
else:
    print("Cannot be represented by a single denomination")
# Out:
# Enter a amount50
# Cannot be represented by a single denomination

# %%
#11. Write a Python program to input angles of a triangle and check whether triangle is valid or not.
angle1=eval(input('Enter first angle'))
angle2=eval(input('Enter second angle'))
angle3=eval(input('enter third angle'))
if angle1 >=1 and angle2 >=2 and angle3 >=3 and(angle1+angle2+angle3==180):
  print('Triangle is valid')
else:
  print('Triangle is not valid')
# Out:
# Enter first angle50
# Enter second angle60
# enter third angle50
# Triangle is not valid

# %%
#12. Write a Python program to input all sides of a triangle and check whether triangle is valid or not.
side1=eval(input('Enter first side'))
side2=eval(input('Enter second side'))
side3=eval(input('Enter third side'))
if (side1 + side2 >side3) and(side1 + side3 >side2)and(side2 + side3 >side1):
  print('triangle is valid')
else:
  print('trianle is not valid')
# Out:
# Enter first side5
# Enter second side3
# Enter third side1
# trianle is not valid
