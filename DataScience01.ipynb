# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/course-of-python/blob/main/DataScience01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science

# %%
#Bringing insights from data is nothing but Data Science
#This Data Science helps u to built a strong domain knowledge

#We have 4 important libraries
#Numpy-Numeric Python:Array + numeric operation
#Pandas-Data Analysis + plotting
#Matplotlib-plotting and analysis
#Seaborn:plotting and analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/CO2%20Emissions_Canada.csv"
path
# Out:
# 'https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/CO2%20Emissions_Canada.csv'

# %%
#load dataset using pandas
df=pd.read_csv(path)
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %%
#check rows and columns
df.shape #columns =12 ,rows=7385
# Out:
# (7385, 12)

# %%
#show me the columns names
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
#show me the abstract summary of my data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
#check data type of df
df.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
#access one column using dot operator
df.Make
# Out:
# 0       ACURA
# 1       ACURA
# 2       ACURA
# 3       ACURA
# 4       ACURA
#         ...
# 7380    VOLVO
# 7381    VOLVO
# 7382    VOLVO
# 7383    VOLVO
# 7384    VOLVO
# Name: Make, Length: 7385, dtype: object

# %%
df.Vehicle Class
# Out:
#   File "/tmp/ipykernel_4070/1682661518.py", line 1
#     df.Vehicle Class
#                ^
# SyntaxError: invalid syntax

# %%
#above error is bcz of space
#then use another approach of []

df['Vehicle Class']
# Out:
# 0              COMPACT
# 1              COMPACT
# 2              COMPACT
# 3          SUV - SMALL
# 4          SUV - SMALL
#              ...
# 7380       SUV - SMALL
# 7381       SUV - SMALL
# 7382       SUV - SMALL
# 7383    SUV - STANDARD
# 7384    SUV - STANDARD
# Name: Vehicle Class, Length: 7385, dtype: object

# %%
df['Engine Size(L)']
# Out:
# 0       2.0
# 1       2.4
# 2       1.5
# 3       3.5
# 4       3.5
#        ...
# 7380    2.0
# 7381    2.0
# 7382    2.0
# 7383    2.0
# 7384    2.0
# Name: Engine Size(L), Length: 7385, dtype: float64

# %%
df['Fuel Consumption Comb (L/100 km)']
# Out:
# 0        8.5
# 1        9.6
# 2        5.9
# 3       11.1
# 4       10.6
#         ...
# 7380     9.4
# 7381     9.9
# 7382    10.3
# 7383     9.9
# 7384    10.7
# Name: Fuel Consumption Comb (L/100 km), Length: 7385, dtype: float64

# %%
#python is case sensitive
#pandas is also case sensitive

# %%
#i need unique Vehicle classes
df['Vehicle Class'].unique()
# Out:
# array(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
#        'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
#        'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
#        'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL'], dtype=object)

# %%
#How many unique Vehicle classes
df['Vehicle Class'].nunique()
# Out:
# 16

# %%
#now i want per category count for Vehicle class
df['Vehicle Class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_803/3030821178.py in <cell line: 0>()
#       1 #now i want per category count for Vehicle class
# ----> 2 df['Vehicle Class'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#plot above record using Seaborn
sns.countplot(x='Vehicle Class',data=df)
# Out:
# <Axes: xlabel='Vehicle Class', ylabel='count'>

# %%
sns.countplot(x='Vehicle Class',data=df)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_803/2867316011.py in <cell line: 0>()
# ----> 1 sns.countplot(x='Vehicle Class',data=df)
#       2 plt.xticks(rotation=90)
#
# NameError: name 'sns' is not defined

# %%
sns.countplot(x='Vehicle Class',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#Boolean indexing
df[df['Cylinders']>5]
# Out:
#         Make                              Model            Vehicle Class  \
# 3      ACURA                            MDX 4WD              SUV - SMALL
# 4      ACURA                            RDX AWD              SUV - SMALL
# 5      ACURA                                RLX                 MID-SIZE
# 6      ACURA                                 TL                 MID-SIZE
# 7      ACURA                             TL AWD                 MID-SIZE
# ...      ...                                ...                      ...
# 7353  TOYOTA                         Tacoma 4WD     PICKUP TRUCK - SMALL
# 7354  TOYOTA                         Tacoma 4WD     PICKUP TRUCK - SMALL
# 7355  TOYOTA  Tacoma 4WD D-Cab TRD Off-Road/Pro     PICKUP TRUCK - SMALL
# 7356  TOYOTA                             Tundra  PICKUP TRUCK - STANDARD
# 7357  TOYOTA                         Tundra 4WD  PICKUP TRUCK - STANDARD
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 3                3.5          6          AS6         Z
# 4                3.5          6          AS6         Z
# 5                3.5          6          AS6         Z
# 6                3.5          6          AS6         Z
# 7                3.7          6          AS6         Z
# ...              ...        ...          ...       ...
# 7353             3.5          6          AS6         X
# 7354             3.5          6           M6         X
# 7355             3.5          6           M6         X
# 7356             5.7          8          AS6         X
# 7357             5.7          8          AS6         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 3                                 12.7                              9.1
# 4                                 12.1                              8.7
# 5                                 11.9                              7.7
# 6                                 11.8                              8.1
# 7                                 12.8                              9.0
# ...                                ...                              ...
# 7353                              13.0                             10.5
# 7354                              13.8                             11.4
# 7355                              13.8                             11.7
# 7356                              17.7                             13.6
# 7357                              18.0                             14.2
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 3                                 11.1                           25
# 4                                 10.6                           27
# 5                                 10.0                           28
# 6                                 10.1                           28
# 7                                 11.1                           25
# ...                                ...                          ...
# 7353                              11.9                           24
# 7354                              12.7                           22
# 7355                              12.9                           22
# 7356                              15.9                           18
# 7357                              16.3                           17
#
#       CO2 Emissions(g/km)
# 3                     255
# 4                     244
# 5                     230
# 6                     232
# 7                     255
# ...                   ...
# 7353                  278
# 7354                  299
# 7355                  300
# 7356                  371
# 7357                  381
#
# [4044 rows x 12 columns]

# %%
#np.nan represent a missing value, NaN is afloating value ,NAN
