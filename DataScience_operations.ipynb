# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/course-of-python/blob/main/DataScience_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science Operations

# %%
path='/content/CO2 Emissions_Canada.csv'

# %%
#loading the dataset

import pandas as pd

c=pd.read_csv(path)
c.head(2)
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# #Filter based selection/conditonal selection

# %%
c[:2]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
c['Make'].unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %%
#Select only  records of BMW
#c.query("expression")

c.query("Make=='BMW'")
# Out:
#      Make                Model          Vehicle Class  Engine Size(L)  \
# 76    BMW                 320i                COMPACT             2.0
# 77    BMW                 320i                COMPACT             2.0
# 78    BMW          320i xDRIVE                COMPACT             2.0
# 79    BMW          328d xDRIVE                COMPACT             2.0
# 80    BMW  328d xDRIVE TOURING  STATION WAGON - SMALL             2.0
# ...   ...                  ...                    ...             ...
# 6635  BMW         X7 xDrive40i         SUV - STANDARD             3.0
# 6636  BMW         X7 xDrive50i         SUV - STANDARD             4.4
# 6637  BMW              X7 M50i         SUV - STANDARD             4.4
# 6638  BMW         Z4 sDrive30i             TWO-SEATER             2.0
# 6639  BMW              Z4 M40i             TWO-SEATER             3.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
c.query("Make=='BMW' and Cylinders>6")
# Out:
#      Make                     Model   Vehicle Class  Engine Size(L)  \
# 103   BMW               550i xDRIVE        MID-SIZE             4.4
# 104   BMW  550i xDRIVE GRAN TURISMO       FULL-SIZE             4.4
# 106   BMW     650i xDRIVE CABRIOLET      SUBCOMPACT             4.4
# 107   BMW         650i xDRIVE COUPE         COMPACT             4.4
# 108   BMW    650i xDRIVE GRAN COUPE         COMPACT             4.4
# ...   ...                       ...             ...             ...
# 6631  BMW              X5 xDrive50i  SUV - STANDARD             4.4
# 6632  BMW                   X5 M50i  SUV - STANDARD             4.4
# 6634  BMW                   X6 M50i  SUV - STANDARD             4.4
# 6636  BMW              X7 xDrive50i  SUV - STANDARD             4.4
# 6637  BMW                   X7 M50i  SUV - STANDARD             4.4
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 103           8           A8         Z                              14.4
# ...

# %%
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
c['Engine Size(L)'].unique()
# Out:
# array([2. , 2.4, 1.5, 3.5, 3.7, 1.8, 5.9, 4.7, 3. , 4. , 6.3, 4.2, 5.2,
#        6. , 6.8, 4.4, 3.6, 1.4, 2.5, 6.2, 4.3, 5.3, 4.8, 1.2, 5.7, 6.4,
#        4.6, 5.4, 1.6, 5. , 1. , 5.8, 3.8, 3.3, 5.6, 3.2, 6.5, 5.5, 2.1,
#        3.4, 2.7, 6.6, 6.7, 1.3, 8.4, 2.3, 2.8, 0.9, 2.9, 8. , 2.2])

# %%
c.query("Make=='BMW' and `Engine Size(L)`>6")
# Out:
#      Make               Model Vehicle Class  Engine Size(L)  Cylinders  \
# 3436  BMW        M760i xDRIVE     FULL-SIZE             6.6         12
# 4495  BMW        M760i xDRIVE     FULL-SIZE             6.6         12
# 5559  BMW       M760Li xDrive     FULL-SIZE             6.6         12
# 6609  BMW  M760i xDrive Sedan     FULL-SIZE             6.6         12
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3436          AS8         Z                              17.7
# 4495          AS8         Z                              17.7
# 5559          AS8         Z                              17.7
# 6609          AS8         Z                              17.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 3436                             11.9                              15.1
# 4495                             11.9                              15.1
# 5559                             11.9                              15.1
# ...

# %%
#Access/Filter data using Indexing
#Boolean Indexing

c[c['Vehicle Class'] =='FULL-SIZE']
# Out:
#              Make                     Model Vehicle Class  Engine Size(L)  \
# 34           AUDI                       A8L     FULL-SIZE             3.0
# 35           AUDI                       A8L     FULL-SIZE             4.0
# 36           AUDI                       A8L     FULL-SIZE             6.3
# 37           AUDI        A8L TDI (modified)     FULL-SIZE             3.0
# 84            BMW  328i xDRIVE GRAN TURISMO     FULL-SIZE             2.0
# ...           ...                       ...           ...             ...
# 7290  ROLLS-ROYCE                   Phantom     FULL-SIZE             6.7
# 7291  ROLLS-ROYCE               Phantom EWB     FULL-SIZE             6.7
# 7304       SUBARU                Legacy AWD     FULL-SIZE             2.4
# 7305       SUBARU                Legacy AWD     FULL-SIZE             2.5
# 7360   VOLKSWAGEN            Arteon 4MOTION     FULL-SIZE             2.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
c[:1]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196

# %%
c['Make']=='ACURA'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7380    False
# 7381    False
# 7382    False
# 7383    False
# 7384    False
# Name: Make, Length: 7385, dtype: bool

# %%
c[c['Make']=='ACURA']
# Out:
#        Make                              Model Vehicle Class  Engine Size(L)  \
# 0     ACURA                                ILX       COMPACT             2.0
# 1     ACURA                                ILX       COMPACT             2.4
# 2     ACURA                         ILX HYBRID       COMPACT             1.5
# 3     ACURA                            MDX 4WD   SUV - SMALL             3.5
# 4     ACURA                            RDX AWD   SUV - SMALL             3.5
# ...     ...                                ...           ...             ...
# 6508  ACURA                     RDX AWD A-SPEC   SUV - SMALL             2.0
# 6509  ACURA                         RLX Hybrid      MID-SIZE             3.5
# 6510  ACURA                         TLX A-SPEC       COMPACT             2.4
# 6511  ACURA                         TLX SH-AWD       COMPACT             3.5
# 6512  ACURA  TLX SH-AWD A-SPEC/Limited Edition       COMPACT             3.5
#
# ...

# %%
#Use bitwise & operator as we have multiple True False comparisons
#Logical and wont work here as it is onlyfor single comparison
 c[(c['Make']=='ACURA') & (c['Cylinders']==6)]
# Out:
#   File "/tmp/ipykernel_1034/1121271400.py", line 3
#     c[(c['Make']=='ACURA') & (c['Cylinders']==6)]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# #Groupby operations

# %%
c[:1]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196

# %%
list(c.groupby(['Make']))
# Out:
# [(('ACURA',),
#          Make                              Model Vehicle Class  Engine Size(L)  \
#   0     ACURA                                ILX       COMPACT             2.0
#   1     ACURA                                ILX       COMPACT             2.4
#   2     ACURA                         ILX HYBRID       COMPACT             1.5
#   3     ACURA                            MDX 4WD   SUV - SMALL             3.5
#   4     ACURA                            RDX AWD   SUV - SMALL             3.5
#   ...     ...                                ...           ...             ...
#   6508  ACURA                     RDX AWD A-SPEC   SUV - SMALL             2.0
#   6509  ACURA                         RLX Hybrid      MID-SIZE             3.5
#   6510  ACURA                         TLX A-SPEC       COMPACT             2.4
#   6511  ACURA                         TLX SH-AWD       COMPACT             3.5
#   6512  ACURA  TLX SH-AWD A-SPEC/Limited Edition       COMPACT             3.5
#
# ...

# %%
#fetch a particular group
c.groupby(['Make']).get_group('TOYOTA')
# Out:
# /tmp/ipykernel_1034/69616798.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   c.groupby(['Make']).get_group('TOYOTA')
#         Make                              Model            Vehicle Class  \
# 970   TOYOTA            4RUNNER (Part-Time 4WD)           SUV - STANDARD
# 971   TOYOTA                        4RUNNER 4WD           SUV - STANDARD
# 972   TOYOTA                             AVALON                 MID-SIZE
# 973   TOYOTA                              CAMRY                 MID-SIZE
# 974   TOYOTA                              CAMRY                 MID-SIZE
# ...      ...                                ...                      ...
# 7355  TOYOTA  Tacoma 4WD D-Cab TRD Off-Road/Pro     PICKUP TRUCK - SMALL
# 7356  TOYOTA                             Tundra  PICKUP TRUCK - STANDARD
# ...

# %%
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
cols=['Fuel Consumption City (L/100 km)',
       'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
       'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']
c.groupby(['Make']).get_group('TOYOTA').loc[:,cols].agg([min,max,np.mean])
# Out:
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# min                               4.30                         4.500000
# max                              19.00                        14.200000
# mean                             10.63                         8.449394
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# min                           4.400000                    17.000000
# max                          16.700000                    64.000000
# mean                          9.640606                    32.536364
#
#       CO2 Emissions(g/km)
# min            104.000000
# max            385.000000
# mean           224.424242

# %%
c.groupby(['Make'])[cols].agg([min,max,np.mean])
# Out:
#               Fuel Consumption City (L/100 km)                   \
#                                            min   max       mean
# Make
# ACURA                                      6.0  13.4  10.797222
# ALFA ROMEO                                 9.7  14.1  10.966667
# ASTON MARTIN                              12.7  23.2  17.091489
# AUDI                                       7.6  21.2  12.431818
# BENTLEY                                   15.1  24.5  18.965217
# BMW                                        7.6  18.7  12.611575
# BUGATTI                                   26.8  26.8  26.800000
# BUICK                                      8.5  19.4  11.802913
# CADILLAC                                   9.8  25.7  13.375949
# CHEVROLET                                  4.8  30.6  13.772109
# CHRYSLER                                  10.2  19.7  14.020455
# DODGE                                      8.4  19.9  14.843902
# FIAT                                       7.6  11.0   9.227397
# ...
